# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from time import time
plt.rcParams['figure.figsize'] = (8.0, 8.0)

# %%
np.random.seed(0)

# %%
def generate_samples(m, b, size=20):
    
    x = np.random.random(size) * 75 + 2
    
    y = m * x + b
    
    y_range = (y.max() - y.min())
    
    sigma = np.random.randn(size) * 0.1 * y_range
    sigma = sigma + 2 * (sigma/abs(sigma))
    y = y + sigma
    
    return x, y, sigma

# %%
x, y, y_err  = generate_samples(0.736, 30)
def plot_data(x, y, y_err):
    plt.figure()
    plt.errorbar(x, y, yerr=y_err, color='black', linestyle='', marker='^', capsize=4)
    plt.xlim([x.min() - 30, x.max() + 30])
    plt.ylim([y.min() - 50, y.max() + 50])
    plt.xlabel("x")
    plt.ylabel("y")

# %%
plot_data(x, y, y_err)
plt.show()

# %% [markdown]
# Want to find $Pr(m,\, b\, |\, Assumptions)$

# %% [markdown]
# ### posterior distribution (parameter(s) | data) = sampling distribution (data | parameter(s)) * prior distribution ( parameters) / evidence (data)
# Note : sampling distribution with known data = likelihood
# ### Therefore: ln(posterior distribution) = ln(sampling distribution) + ln(prior distribution) - log(evidence)
#
# sampling distribution = gaussian deviation from a straight line equation
#
# prior distribution = uniform distribution
#
# evidence = will not be considered as it acts as a normalisation factor only.

# %%
def natural_log_likelihood(parameters, x, y, error):
    """
    Computes the gaussian of the deviation from the analytic straight line y = mx + b
    
    gauss = 1/(sqrt(2 * pi) * error) * exp(- 0.5 * ((y - m * x - b) ** 2 ) / error)
    ln(gauss) = ln(1/(sqrt(2 * pi) * error)) + (- 0.5 * ((y - m * x - b) ** 2 ) / error)
    
    ln(gauss) needs to then be reduced to a signle probablility via summation
    """
    m, b = parameters

    return (np.sum(np.log(1./(np.sqrt(2.*np.pi) * error))) +
            np.sum(-0.5 * (y - (m*x + b))**2 / error**2))


def log_uniform_prior_dist(parameters, limits):
    """
    returns log of uniform distribution if within limits, -infinity otherwise
    """
    m, b = parameters
    
    mlimits, blimits = limits
    
    if (m >= mlimits[0]) and (m <= mlimits[1]):
        log_uniform_prior_m = np.log(1.0/(mlimits[1] - mlimits[0]))
    else:
        log_uniform_prior_m = -np.inf
    if (b >= blimits[0]) and (b <= blimits[1]):
        log_uniform_prior_b = np.log(1.0/(blimits[1] - blimits[0]))
    else:
        log_uniform_prior_b = -np.inf
        
    return log_uniform_prior_m + log_uniform_prior_b


def natural_log_post_disribution(parameters, x, y, error, param_limits):
    """
    multiplication becomes addition as the log of the probability is taken
    """
    return natural_log_likelihood(parameters, x, y, error) + log_uniform_prior_dist(parameters, param_limits)

# %% [markdown]
# Sample values for m and b using the Markov Chain Monte Carlo Methods : The Metropolis Algorithm

# %% [markdown]
# Metropolis Algorithm procedure:
# 1. Sample a point from the posterior distribution
# 2. Symmetrically sample a second point around the last point
# 3. IF posterior(x$_{i+1}$) > posterior(x$_{i}$) accept the new point
#    ELSE generate a uniform random number (n$_r$) in \[0, 1\] and accept if $\frac{p(x_{i+1})}{p(x_i)} > n_r$
# 4. Repeat 2 and 3 for N times.

# %%
def Metropolis(posterior_function, data, parameters, param_limits, stepsizes, nsteps=10000):
    
    x, y, error = data
    
    # Generating an initial position probability
    log_post = posterior_function(parameters, x, y, error, param_limits)
    # print(log_post)

    markov_chain = np.empty((nsteps, len(parameters)))
    log_probabilities = np.empty(nsteps)
    n_accepted = 0
    
    for i in range(nsteps):
        new_params = parameters + stepsizes * np.random.randn(len(parameters))
        new_log_post = posterior_function(new_params, x, y, error, param_limits)
        # print(new_log_post)
        if new_log_post > log_post:
            parameters = new_params
            log_post = new_log_post
            n_accepted += 1
        else:
            n_rand = np.log(np.random.random())
            if n_rand < (new_log_post - log_post):
                parameters = new_params
                log_post = new_log_post
                n_accepted += 1
            else:
                pass
        markov_chain[i] = parameters
        log_probabilities[i] = log_post
        
    acceptance = n_accepted / nsteps
    return markov_chain, log_probabilities, acceptance

# %%
start_parameters = np.array([0.5, 10])
mlimits, blimits = ((0.01, 2), (0.1, 50))

stepsize_m = 0.02 * (mlimits[1] - mlimits[0])
stepsize_b = 0.05 * (blimits[1] - blimits[0])

stepsize = np.array([stepsize_m, stepsize_b])

data = (x, y, abs(y_err))

print("Sampling using Metropolis Algorithm")

t = time()
for i in range(1000):
    chain, log_probs, acceptance = Metropolis(natural_log_post_disribution, data, start_parameters, (mlimits, blimits), stepsize, nsteps=1000)
t = (time() - t) / 1000
print(f"Ran with acceptance rate of {acceptance} in {t} seconds")
# Out:
# Sampling using Metropolis Algorithm
# Ran with acceptance rate of 0.301 in 0.07365679478645325 seconds

# %%
def plot_chain(chain, mlimits, blimits):
    fig, ax = plt.subplots(2, 1)
    ax[0].plot(chain[:, 0], 'k-')
    ax[0].set_ylabel("Gradient of data (m)")
    ax[0].set_ylim(*mlimits)
    ax[0].set_xticks([])
    ax[1].set_ylabel("Intercept of data (b)")
    ax[1].set_ylim(*blimits)
    ax[1].set_xlabel("Sample Number")
    ax[1].plot(chain[:, 1], 'k-')

# %%
plot_chain(chain, mlimits, blimits)
plt.show()

# %%
def plot_PDF_walk(chain, start_parameters, mlimits, blimits, title="MCMC: Posterior PDF for parameters m and b"):
    plt.figure()
    plt.plot(chain[:, 1], chain[:, 0], linestyle="", marker='o', alpha=0.01, color="blue")
    plt.plot(start_parameters[1], start_parameters[0], linestyle="", marker='o', alpha=1, color="red", label="RW Starting Position")
    plt.ylim(*mlimits)
    plt.xlim(*blimits)
    plt.title(title)
    plt.legend()
    plt.ylabel("Gradient of data (m)")
    plt.xlabel("Intercept of data (b)")

# %%
plot_PDF_walk(chain, start_parameters, mlimits, blimits, title="MCMC: Posterior PDF for parameters m and b")
plt.show()

# %%
import corner
corner.corner(chain[500:], labels=['m','b'], range=[mlimits,blimits],quantiles=[0.16,0.5,0.84],
                show_titles=True, title_args={"fontsize": 12},
                plot_datapoints=True, fill_contours=True, levels=[0.68, 0.95], 
                color='b', bins=80, smooth=1.0);

# %% [markdown]
# Performed estimates using corner and extracted the median values of the simulated parameter distributions.
#
# The estimates are incredibly accurate as $m_{estimated} = 0.71 \pm 0.05$, compared to a true value of $m = 0.736$;  and $b_{estimated} = 31.97 (+2.24, -2.25)$, compared to a true value of $b=30$. Both are with estimated error range.

# %% [markdown]
# ## Check the Model

# %%
x_axis = np.linspace(x.min() - 30, x.max() + 30, 50)

plot_data(x, y, y_err)

for i in np.random.randint(len(chain), size=100):
    m, b = chain[i]
    plt.plot(x_axis, m* x_axis + b, color='blue', alpha=0.1)
plt.show()

# %% [markdown]
# # Performing the same procedure using a Fortran engine

# %%
# !rm FortranEngine.cpython-36m-x86_64-linux-gnu.so 
# !f2py3 engine.f90 -m FortranEngine -c
# Out:
# running build
# running config_cc
# unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# build_src
# building extension "FortranEngine" sources
# f2py options: []
# f2py:> /tmp/tmp08xdav23/src.linux-x86_64-3.6/FortranEnginemodule.c
# creating /tmp/tmp08xdav23/src.linux-x86_64-3.6
# Reading fortran codes...
# 	Reading file 'engine.f90' (format:free)
# Post-processing...
# 	Block: FortranEngine
# 			Block: data_generator
# 				Block: generate_data
# 				Block: gaussian_sampling
# appenddecl: "dimension" not implemented.
# 				Block: box_miller
# In: :FortranEngine:engine.f90:data_generator:box_miller
# get_parameters: got "name 'atan' is not defined" on '4*atan(1.0)'
# 			Block: probability
# In: :FortranEngine:engine.f90:probability
# get_parameters: got "name 'atan' is not defined" on '4*atan(1.0)'
# 				Block: log_likelihood
# 				Block: ln_uniform_prior_dist
# 				Block: ln_posterior_dist
# 			Block: mcmc
# 				Block: metropolis
# In: :FortranEngine:engine.f90:mcmc:metropolis
# get_parameters: got "name 'atan' is not defined" on '4*atan(1.0)'
# Post-processing (stage 2)...
# 	Block: FortranEngine
# 		Block: unknown_interface
# 			Block: data_generator
# 				Block: generate_data
# 				Block: gaussian_sampling
# 				Block: box_miller
# 			Block: probability
# 				Block: log_likelihood
# 				Block: ln_uniform_prior_dist
# 				Block: ln_posterior_dist
# 			Block: mcmc
# 				Block: metropolis
# Building modules...
# 	Building module "FortranEngine"...
# 		Constructing F90 module support for "data_generator"...
# 			Constructing wrapper function "data_generator.generate_data"...
# 			  x,y,sigmay = generate_data(m,b,n_elements)
# 		Creating wrapper for Fortran function "gaussian_sampling"("gaussian_sampling")...
# 			Constructing wrapper function "data_generator.gaussian_sampling"...
# 			  normal = gaussian_sampling(n_elements)
# 			Constructing wrapper function "data_generator.box_miller"...
# 			  normal = box_miller(uniform)
# 		Constructing F90 module support for "probability"...
# 		  Variables: pi_16
# 			Constructing wrapper function "probability.log_likelihood"...
# 			  res = log_likelihood(parameters,x,y,error,[n_elements])
# 			Constructing wrapper function "probability.ln_uniform_prior_dist"...
# 			  res = ln_uniform_prior_dist(parameters,limits)
# 			Constructing wrapper function "probability.ln_posterior_dist"...
# 			  res = ln_posterior_dist(parameters,x,y,error,limits,[n_elements])
# 		Constructing F90 module support for "mcmc"...
# 			Constructing wrapper function "mcmc.metropolis"...
# 			  chain_res,log_array,acceptance = metropolis(data_block,parameters,limits,stepsize,n_iter,[n_elements])
# 	Wrote C/API module "FortranEngine" to file "/tmp/tmp08xdav23/src.linux-x86_64-3.6/FortranEnginemodule.c"
# 	Fortran 90 wrappers are saved to "/tmp/tmp08xdav23/src.linux-x86_64-3.6/FortranEngine-f2pywrappers2.f90"
#   adding '/tmp/tmp08xdav23/src.linux-x86_64-3.6/fortranobject.c' to sources.
#   adding '/tmp/tmp08xdav23/src.linux-x86_64-3.6' to include_dirs.
# copying /home/giuseppe/.local/lib/python3.6/site-packages/numpy/f2py/src/fortranobject.c -> /tmp/tmp08xdav23/src.linux-x86_64-3.6
# copying /home/giuseppe/.local/lib/python3.6/site-packages/numpy/f2py/src/fortranobject.h -> /tmp/tmp08xdav23/src.linux-x86_64-3.6
#   adding '/tmp/tmp08xdav23/src.linux-x86_64-3.6/FortranEngine-f2pywrappers2.f90' to sources.
# build_src: building npy-pkg config files
# running build_ext
# customize UnixCCompiler
# customize UnixCCompiler using build_ext
# get_default_fcompiler: matching types: '['gnu95', 'intel', 'lahey', 'pg', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor']'
# customize Gnu95FCompiler
# Found executable /usr/bin/gfortran
# customize Gnu95FCompiler
# customize Gnu95FCompiler using build_ext
# building 'FortranEngine' extension
# compiling C sources
# C compiler: x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
# creating /tmp/tmp08xdav23/tmp
# creating /tmp/tmp08xdav23/tmp/tmp08xdav23
# creating /tmp/tmp08xdav23/tmp/tmp08xdav23/src.linux-x86_64-3.6
# compile options: '-I/tmp/tmp08xdav23/src.linux-x86_64-3.6 -I/home/giuseppe/.local/lib/python3.6/site-packages/numpy/core/include -I/usr/include/python3.6m -c'
# x86_64-linux-gnu-gcc: /tmp/tmp08xdav23/src.linux-x86_64-3.6/fortranobject.c
# x86_64-linux-gnu-gcc: /tmp/tmp08xdav23/src.linux-x86_64-3.6/FortranEnginemodule.c
# In file included from /home/giuseppe/.local/lib/python3.6/site-packages/numpy/core/include/numpy/ndarraytypes.h:1832:0,
#                  from /home/giuseppe/.local/lib/python3.6/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /home/giuseppe/.local/lib/python3.6/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from /tmp/tmp08xdav23/src.linux-x86_64-3.6/fortranobject.h:13,
#                  from /tmp/tmp08xdav23/src.linux-x86_64-3.6/fortranobject.c:2:
# /home/giuseppe/.local/lib/python3.6/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# In file included from /home/giuseppe/.local/lib/python3.6/site-packages/numpy/core/include/numpy/ndarraytypes.h:1832:0,
#                  from /home/giuseppe/.local/lib/python3.6/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /home/giuseppe/.local/lib/python3.6/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from /tmp/tmp08xdav23/src.linux-x86_64-3.6/fortranobject.h:13,
#                  from /tmp/tmp08xdav23/src.linux-x86_64-3.6/FortranEnginemodule.c:16:
# /home/giuseppe/.local/lib/python3.6/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it with " \
#   ^~~~~~~
# /tmp/tmp08xdav23/src.linux-x86_64-3.6/FortranEnginemodule.c:148:12: warning: ‘f2py_size’ defined but not used [-Wunused-function]
#  static int f2py_size(PyArrayObject* var, ...)
#             ^~~~~~~~~
# compiling Fortran 90 module sources
# Fortran f77 compiler: /usr/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: /usr/bin/gfortran -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran fix compiler: /usr/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# compile options: '-I/tmp/tmp08xdav23/src.linux-x86_64-3.6 -I/home/giuseppe/.local/lib/python3.6/site-packages/numpy/core/include -I/usr/include/python3.6m -c'
# extra options: '-J/tmp/tmp08xdav23/ -I/tmp/tmp08xdav23/'
# gfortran:f90: engine.f90
# engine.f90:50:20:
#
#          normal(1) = SQRT(-2 * LOG(uniform(1))) * COS(2 * PI_16 * uniform(2))
#                     1
# Warning: Possible change of value in conversion from REAL(16) to REAL(4) at (1) [-Wconversion]
# engine.f90:51:20:
#
#          normal(2) = SQRT(-2 * LOG(uniform(2))) * COS(2 * PI_16 * uniform(1))
#                     1
# Warning: Possible change of value in conversion from REAL(16) to REAL(4) at (1) [-Wconversion]
# engine.f90:30:24:
#
#          half_elements = n_elements / 2
#                         1
# Warning: Possible change of value in conversion from INTEGER(4) to INTEGER(2) at (1) [-Wconversion]
# engine.f90:68:14:
#
#          res = SUM(LOG(1/(SQRT(2 * PI_16) * ABS(error)))) + &
#               1
# Warning: Possible change of value in conversion from REAL(16) to REAL(4) at (1) [-Wconversion]
# compiling Fortran sources
# Fortran f77 compiler: /usr/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran f90 compiler: /usr/bin/gfortran -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# Fortran fix compiler: /usr/bin/gfortran -Wall -g -ffixed-form -fno-second-underscore -Wall -g -fno-second-underscore -fPIC -O3 -funroll-loops
# compile options: '-I/tmp/tmp08xdav23/src.linux-x86_64-3.6 -I/home/giuseppe/.local/lib/python3.6/site-packages/numpy/core/include -I/usr/include/python3.6m -c'
# extra options: '-J/tmp/tmp08xdav23/ -I/tmp/tmp08xdav23/'
# gfortran:f90: /tmp/tmp08xdav23/src.linux-x86_64-3.6/FortranEngine-f2pywrappers2.f90
# /usr/bin/gfortran -Wall -g -Wall -g -shared /tmp/tmp08xdav23/tmp/tmp08xdav23/src.linux-x86_64-3.6/FortranEnginemodule.o /tmp/tmp08xdav23/tmp/tmp08xdav23/src.linux-x86_64-3.6/fortranobject.o /tmp/tmp08xdav23/engine.o /tmp/tmp08xdav23/tmp/tmp08xdav23/src.linux-x86_64-3.6/FortranEngine-f2pywrappers2.o -L/usr/lib/gcc/x86_64-linux-gnu/7 -L/usr/lib/gcc/x86_64-linux-gnu/7 -lgfortran -o ./FortranEngine.cpython-36m-x86_64-linux-gnu.so
# Removing build directory /tmp/tmp08xdav23

# %%
import FortranEngine
print(dir(FortranEngine))
# Out:
# ['_FortranEngine_error', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__version__', 'data_generator', 'mcmc', 'probability']

# %%
m, b = (0.736, 30)
x, y, y_err = FortranEngine.data_generator.generate_data(m, b, 20)

plot_data(x, y, y_err)
plt.show()

# %%
out= FortranEngine.probability.log_likelihood(np.array([m, b]), x, y, y_err, 20)

# %%
print(out)
# Out:
# -60.640594482421875

# %%
# FINISH IMPLEMENTING THE PROBABILITIES IN FORTRAN

# %%
parameters = np.array([2, 0.5])
limits = np.array([[0, 4],
                  [0, 1]])
out = FortranEngine.probability.ln_uniform_prior_dist(parameters, limits)

# %%
print(out)
# Out:
# -1.3862943649291992

# %%
log_uniform_prior_dist(parameters, limits)
# Out:
# -1.3862943611198906

# %%
parameters = np.array([2, 0.5])
limits = np.array([[0, 4],
                  [0, 1]])
out = FortranEngine.probability.ln_posterior_dist(parameters, x, y, y_err, limits, 20)
print(out)
# Out:
# -906.2378540039062

# %%
print(natural_log_post_disribution(parameters, x, y, abs(y_err), limits))
# Out:
# -906.2377958259636

# %%
start_parameters = np.array([0.5, 10])
# mlimits, blimits = ((0.01, 2), (0.1, 50))
limits = np.array([[0.01, 2.0],
                  [0.1, 50.0]])
stepsize_m = 0.02 * (limits[0, 1] - limits[0, 0])
stepsize_b = 0.05 * (limits[1, 1] - limits[1, 0])

stepsize = np.array([stepsize_m, stepsize_b])
data = (x, y, abs(y_err))



t = time()
for i in range(1000):
    chain, probs, acceptance = FortranEngine.mcmc.metropolis(data, start_parameters, limits, stepsize, 1000, 20)
t = (time() - t) / 1000

print(f"The MCMC simulation ran with an acceptance rate of {acceptance} in {t} seconds")
# Out:
# The MCMC simulation ran with an acceptance rate of 0.3240000009536743 in 0.028436250448226928 seconds

# %%
plot_chain(chain, *limits)
plt.show()

# %%
plot_PDF_walk(chain, start_parameters, limits[0], limits[1], title="Fortran MCMC: Estimating m and b")
plt.show()

# %%
corner.corner(chain[500:], labels=['m','b'], range=[mlimits,blimits],quantiles=[0.16,0.5,0.84],
                show_titles=True, title_args={"fontsize": 12},
                plot_datapoints=True, fill_contours=True, levels=[0.68, 0.95], 
                color='b', bins=80, smooth=1.0);

# %%
MABP = K1 * PTT**(-2) + K2/PTT + K3
